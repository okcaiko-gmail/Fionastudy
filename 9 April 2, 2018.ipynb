# %%
#9 April 2, 2018       S&P 500: -2.23%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from kneed import DataGenerator, KneeLocator

# %%
data = pd.read_csv("9.csv") 
price1=np.zeros(4779)
price2=np.zeros(4779)
price1=data['Price 04/01/2018'].values
price2=data['Price 04/02/2018'].values
pricechange=(price2-price1)/price1
pricechange.shape
x=np.arange(4779)
plt.plot(x,pricechange)
plt.ylim(-2,10)
plt.show()

# %%
for i in range(4779):
    if pricechange[i]>10:
        print(i,pricechange[i])
        pricechange[i]=0
plt.plot(x,pricechange)
#plt.ylim(-2,10)
plt.show()
# Out:
# 67 25.349999999999994
# 219 29.344827586206904
# 288 19.833333333333332
# 656 14.166666666666666
# 728 22.333333333333336
# 989 21.35714285714286
# 1309 35.19047619047619
# 1542 1459.0
# 1627 138.57142857142856
# 1782 23.365853658536587
# 2063 23.12
# 2091 27473.999999999996
# 2104 45.075949367088604
# 2416 11.407079646017701
# 2434 10.049250535331906
# 3026 329.4347826086957
# 3460 7223.999999999999
# 3483 2095.0
# 3815 139.76923076923075
# 4048 180.48148148148147
# 4098 110.37037037037037
# 4240 24898.999999999996
# 4275 695.4285714285714
# 4436 21.181818181818183
# 4698 2049.0

# %%
cluster_distance=[]
clusters=[]
for k in range(13,50): #try to find the elbow point 
    price3index=np.zeros((4779,2))  #2*4779 table 
    center=(np.random.rand(k)-0.5)*0.1  #random choose centers 
    total=0
    for j in range(100):     #iteration
        for i in range(4779):
            distance=np.abs(pricechange[i]-center)  #distance between each center to each point
            price3index[i]=[np.argmin(distance),np.min(distance)]   #index and shortest distance
        count=np.zeros((k,2))
        for i in range(4779):
            count[int(price3index[i][0])][0]+=1  #how many stocks in each cluster 
            count[int(price3index[i][0])][1]+=pricechange[i]   #sum of distance in each cluster
            center=count[:,1]/(count[:,0]+1e-9)  #new centers

    for i in range(4779):
        total=total+price3index[i][1] #shortest total distance of each point to its center point
    print('Cluster Number:',k,'Total Distance:',total)
    cluster_distance.append(total)
    clusters.append(k)
# Out:
# Cluster Number: 13 Total Distance: 43.91282009601384
# Cluster Number: 14 Total Distance: 39.81445795716304
# Cluster Number: 15 Total Distance: 37.93805075521577
# Cluster Number: 16 Total Distance: 35.92605218475058
# Cluster Number: 17 Total Distance: 31.990670601944803
# Cluster Number: 18 Total Distance: 31.37392095731624
# Cluster Number: 19 Total Distance: 27.639904914422434
# Cluster Number: 20 Total Distance: 26.68873750566261
# Cluster Number: 21 Total Distance: 26.27247959495503
# Cluster Number: 22 Total Distance: 24.703935621591263
# Cluster Number: 23 Total Distance: 25.306135547299277
# Cluster Number: 24 Total Distance: 24.192921126476424
# Cluster Number: 25 Total Distance: 23.997835603990183
# Cluster Number: 26 Total Distance: 22.740775029305468
# Cluster Number: 27 Total Distance: 22.57131333157918
# Cluster Number: 28 Total Distance: 21.85929693518189
# Cluster Number: 29 Total Distance: 21.7700823851697
# Cluster Number: 30 Total Distance: 20.8636591435345
# Cluster Number: 31 Total Distance: 20.24730610652113
# Cluster Number: 32 Total Distance: 20.151001550363635
# Cluster Number: 33 Total Distance: 19.494808145653966
# Cluster Number: 34 Total Distance: 18.93067175996898
# Cluster Number: 35 Total Distance: 19.371394010887215
# Cluster Number: 36 Total Distance: 18.877661855903764
# Cluster Number: 37 Total Distance: 19.97680279988288
# Cluster Number: 38 Total Distance: 17.88886785682915
# Cluster Number: 39 Total Distance: 18.765090432155358
# Cluster Number: 40 Total Distance: 19.442124893652817
# Cluster Number: 41 Total Distance: 18.356931835410045
# Cluster Number: 42 Total Distance: 18.5991449626137
# Cluster Number: 43 Total Distance: 17.907388414664155
# Cluster Number: 44 Total Distance: 16.143637848041177
# Cluster Number: 45 Total Distance: 17.457902080335188
# Cluster Number: 46 Total Distance: 17.823141525564957
# Cluster Number: 47 Total Distance: 17.50384169524911
# Cluster Number: 48 Total Distance: 18.249412139598032
# Cluster Number: 49 Total Distance: 17.320263568644144

# %%
fig=plt.figure()

x=clusters
y=cluster_distance

kn=KneeLocator(x, y, curve='convex', direction='decreasing')


plt.plot(x, y,color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=8)

plt.vlines(kn.knee,10, 30,linestyles='dashed',color='orange')

# naming the x axis 
plt.xlabel('Number of Clusters') 
# naming the y axis 
plt.ylabel('Sum Distance of Each Point to its Centroid') 
  
# giving a title to my graph 
plt.title('9 Finding Elbow Point') 
  
# function to show the plot 
plt.show()

# %%
kn.knee
# Out:
# 22

# %%
fig.savefig('9 April2 2018.png')
