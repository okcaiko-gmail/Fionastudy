# %%
#13 July 10, 2018       S&P 500: +0.35%

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from kneed import DataGenerator, KneeLocator

# %%
data = pd.read_csv("13.csv") 
price1=np.zeros(4779)
price2=np.zeros(4779)
price1=data['Price 07/09/2018'].values
price2=data['Price 07/10/2018'].values
pricechange=(price2-price1)/price1
pricechange.shape
x=np.arange(4779)
plt.plot(x,pricechange)
plt.ylim(-2,10)
plt.show()

# %%
for i in range(4779):
    if pricechange[i]>10:
        print(i,pricechange[i])
        pricechange[i]=0
plt.plot(x,pricechange)
#plt.ylim(-2,10)
plt.show()
# Out:
# 67 25.349999999999994
# 219 29.344827586206904
# 288 19.833333333333332
# 293 23.37086092715232
# 728 22.333333333333336
# 989 21.35714285714286
# 1309 35.19047619047619
# 1627 138.57142857142856
# 1782 23.365853658536587
# 2063 23.12
# 2091 27473.999999999996
# 2104 45.075949367088604
# 2416 11.407079646017701
# 2434 10.049250535331906
# 3026 329.4347826086957
# 3435 3225.6666666666665
# 3483 2095.0
# 3815 139.76923076923075
# 4048 180.48148148148147
# 4098 110.37037037037037
# 4275 695.4285714285714
# 4436 21.181818181818183
# 4698 2049.0

# %%
cluster_distance=[]
clusters=[]
for k in range(15,50): #try to find the elbow point 
    price3index=np.zeros((4779,2))  #2*4779 table 
    center=(np.random.rand(k)-0.5)*0.1  #random choose centers 
    total=0
    for j in range(100):     #iteration
        for i in range(4779):
            distance=np.abs(pricechange[i]-center)  #distance between each center to each point
            price3index[i]=[np.argmin(distance),np.min(distance)]   #index and shortest distance
        count=np.zeros((k,2))
        for i in range(4779):
            count[int(price3index[i][0])][0]+=1  #how many stocks in each cluster 
            count[int(price3index[i][0])][1]+=pricechange[i]   #sum of distance in each cluster
            center=count[:,1]/(count[:,0]+1e-9)  #new centers

    for i in range(4779):
        total=total+price3index[i][1] #shortest total distance of each point to its center point
    print('Cluster Number:',k,'Total Distance:',total)
    cluster_distance.append(total)
    clusters.append(k)
# Out:
# Cluster Number: 15 Total Distance: 31.99344466710195
# Cluster Number: 16 Total Distance: 28.862194682114843
# Cluster Number: 17 Total Distance: 27.229886634841733
# Cluster Number: 18 Total Distance: 26.151812274950693
# Cluster Number: 19 Total Distance: 25.09676487853712
# Cluster Number: 20 Total Distance: 24.42755006398313
# Cluster Number: 21 Total Distance: 23.537103984914943
# Cluster Number: 22 Total Distance: 23.028731934507437
# Cluster Number: 23 Total Distance: 22.271070125016816
# Cluster Number: 24 Total Distance: 21.413382029048936
# Cluster Number: 25 Total Distance: 21.48072503688688
# Cluster Number: 26 Total Distance: 21.204013419227326
# Cluster Number: 27 Total Distance: 19.984231091071077
# Cluster Number: 28 Total Distance: 19.849168216175254
# Cluster Number: 29 Total Distance: 19.62324098868853
# Cluster Number: 30 Total Distance: 18.951582787046604
# Cluster Number: 31 Total Distance: 18.87911747231298
# Cluster Number: 32 Total Distance: 18.777309708600367
# Cluster Number: 33 Total Distance: 18.679863829979606
# Cluster Number: 34 Total Distance: 18.203525388053585
# Cluster Number: 35 Total Distance: 18.81763869069734
# Cluster Number: 36 Total Distance: 17.628073659910505
# Cluster Number: 37 Total Distance: 18.113029976741114
# Cluster Number: 38 Total Distance: 17.720434934140684
# Cluster Number: 39 Total Distance: 17.413782037184525
# Cluster Number: 40 Total Distance: 17.646266631157488
# Cluster Number: 41 Total Distance: 17.241784832515712
# Cluster Number: 42 Total Distance: 17.225636466771988
# Cluster Number: 43 Total Distance: 16.84498055063829
# Cluster Number: 44 Total Distance: 16.797884241534497
# Cluster Number: 45 Total Distance: 17.07601936675451
# Cluster Number: 46 Total Distance: 16.606211202488932
# Cluster Number: 47 Total Distance: 16.452097847742962
# Cluster Number: 48 Total Distance: 16.234956535377506
# Cluster Number: 49 Total Distance: 16.22272638504091

# %%
fig=plt.figure()

x=clusters
y=cluster_distance

kn=KneeLocator(x, y, curve='convex', direction='decreasing')


plt.plot(x, y,color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=6)

plt.vlines(kn.knee,10, 24,linestyles='dashed',color='orange')

# naming the x axis 
plt.xlabel('Number of Clusters') 
# naming the y axis 
plt.ylabel('Sum Distance of Each Point to its Centroid') 
  
# giving a title to my graph 
plt.title('13 Finding Elbow Point') 
  
# function to show the plot 
plt.show()

# %%
kn.knee
# Out:
# 24

# %%
fig.savefig('13 July10 2018.png')
