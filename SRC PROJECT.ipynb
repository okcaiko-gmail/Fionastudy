# %%
#Important Dates. There are 31 important dates 
#June 28th, 2016     S&P 500: +1.78%
#March 31th, 2017    S&P 500: -0.23%
#April 7, 2017       S&P 500: -0.08%
#July 19, 2017       S&P 500: +0.54%
#Aug. 14, 2017       S&P 500: +1.00%
#Jan. 17, 2018       S&P 500: +0.94%
#Jan. 22, 2018       S&P 500: +0.81%
#March 8, 2018       S&P 500: +0.45%
#April 2, 2018       S&P 500: -2.23%
#April 3, 2018       S&P 500: +1.26%
#April 4, 2018       S&P 500: +1.16%
#June 15, 2018       S&P 500: -0.10%
#July 10, 2018       S&P 500: +0.35%
#Aug. 1, 2018        S&P 500: -0.10%
#Aug. 7, 2018        S&P 500: +0.28%
#Aug. 23, 2018       S&P 500: -0.17%
#Sept. 7, 2018       S&P 500: -0.22%
#Sept. 24, 2018      S&P 500: -0.35%
#Dec. 1, 2018        S&P 500: +1.09% 
#Feb. 24, 2019       S&P 500: +0.12% (Monday, Feb 25)
#May 5, 2019         S&P 500: -0.45% (Monday, May 6)
#May 8, 2019         S&P 500: -0.16%
#June 18, 2019       S&P 500: +0.97%
#June 29, 2019       S&P 500: +0.77% (Monday, July 1)
#Aug. 1, 2019        S&P 500: -0.90%
#Aug. 13, 2019       S&P500:   +1.5%
#Aug. 23, 2019       S&P 500: -0.1%
#Sept. 20, 2019      S&P 500: -0.53%
#Sept. 23, 2019      S&P 500: -0.01%
#Oct. 7, 2019        S&P 500: -0.46%
#Oct. 10, 2019       S&P 500 open: -0.066%

# %%
#What stocks are there in NYSE excel
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from datetime import datetime, timedelta
with open ("data/NYSE.csv") as f:
    lines=f.readlines()
    symbol_ny=[]
    row=len(lines)-1
    for i in range(row):
        tmp=lines[i+1].split(',')
        symbol_ny.append(tmp[0])
print(symbol_ny)
# Out:
# ['"DDD"', '"MMM"', '"WBAI"', '"WUBA"', '"EGHT"', '"AHC"', '"AOS"', '"ATEN"', '"AIR"', '"AAN"', '"ABB"', '"ABT"', '"ABBV"', '"ANF"', '"AGD"', '"AWP"', '"ACP"', '"JEQ"', '"AOD"', '"ABM"', '"AKR"', '"ACN"', '"ACCO"', '"ATV"', '"EPAC"', '"AYI"', '"GOLF"', '"ADX"', '"PEO"', '"AGRO"', '"ADNT"', '"ADT"', '"ATGE"', '"AAP"', '"ADSW"', '"WMS"', '"ASIX"', '"AVK"', '"ACM"', '"AEFC"', '"AEB"', '"AEG"', '"AEH.CL"', '"AER"', '"AJRD"', '"AMG"', '"MGR"', '"AFL"', '"MITT"', '"MITT^A"', '"MITT^B"', '"MITT^C"', '"AGCO"', '"A"', '"AEM"', '"ADC"', '"AL"', '"AL^A"', '"APD"', '"AYR"', '"AKS"', '"ALP^Q"', '"ALG"', '"AGI"', '"ALK"', '"AIN"', '"ALB"', '"AA"', '"ALC"', '"ALEX"', '"ALX"', '"ARE"', '"AQN"', '"AQNA"', '"AQNB"', '"BABA"', '"Y"', '"ATI"', '"ALLE"', '"AGN"', '"ALE"', '"ADS"', '"AFB"', '"AWF"', '"AB"', '"AIO"', '"CBH"', '"NCV"', '"NCV^A"', '"NCZ"', '"NCZ^A"', '"ACV"', '"NIE"', '"NFJ"', '"ALSN"', '"ALL"', '"ALL^A"', '"ALL^B"', '"ALL^G"', '"ALL^H"', '"ALL^I"', '"ALLY"', '"ALLY^A"', '"AYX"', '"ATUS"', '"
# ...

# %%
len(symbol_ny)
# Out:
# 3130

# %%
#downloading stocks through API in NYSE
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
import time

count=0
count_time=time.time()
conflict=0
for i in symbol_ny:
    print(str(count/3130*100)+'%')
    try:
        ts = TimeSeries(key='9QU5M7SRCS3PJ0ES',output_format='pandas')
        data, meta_data = ts.get_daily(symbol=i[1:-1], outputsize='full')
        data.to_csv(i[1:-1]+'.csv')
    except:
        print('error for ',i)
  
    count+=1
    while((time.time()-count_time)<2):
        time.sleep(1)
    count_time=time.time()
# Out:
# 0.0%
# error for  "DDD"
# 0.03194888178913738%
# error for  "MMM"
# 0.06389776357827476%
# error for  "WBAI"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-82cef94182ad> in <module>()
#      19     count+=1
#      20     while((time.time()-count_time)<2):
# ---> 21         time.sleep(1)
#      22     count_time=time.time()
#      23
#
# KeyboardInterrupt:

# %%
available_nyse=[]

for i in symbol_ny: # what NYSE.csv does not have 
    try:
        tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
        available_nyse.append(i)
    except:
        print(r'does not have {0}'.format(i))

count_nyse=len(available_nyse) # what NYSE.csv has
# Out:
# does not have "AEH.CL"
# does not have "MITT^A"
# does not have "MITT^B"
# does not have "MITT^C"
# does not have "AL^A"
# does not have "ALP^Q"
# does not have "NCV^A"
# does not have "NCZ^A"
# does not have "ALL^A"
# does not have "ALL^B"
# does not have "ALL^G"
# does not have "ALL^H"
# does not have "ALL^I"
# does not have "ALLY^A"
# does not have "AEP^B"
# does not have "AMH^D"
# does not have "AMH^E"
# does not have "AMH^F"
# does not have "AMH^G"
# does not have "AMH^H"
# does not have "AIG.WS"
# does not have "AIG^A"
# does not have "NLY^D"
# does not have "NLY^F"
# does not have "NLY^G"
# does not have "NLY^I"
# does not have "ANH^A"
# does not have "ANH^B"
# does not have "ANH^C"
# does not have "APO^A"
# does not have "APO^B"
# does not have "ABR^A"
# does not have "ABR^B"
# does not have "ABR^C"
# does not have "ARES^A"
# does not have "AI^B"
# does not have "AI^C"
# does not have "AHH^A"
# does not have "ARR^B"
# does not have "AHT^D"
# does not have "AHT^F"
# ...

# %%
count_nyse
# Out:
# 2555

# %%
date1=pd.to_datetime('2016-06-28')# which stocks were registered before 6.28.2016 and closed after 10.10.2019 in NYSE
date31=pd.to_datetime('2019-10-10')
aa=[]
for i in available_nyse: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    if (date1 > dates[0]) and (date31 < dates[len(dates)-1]):
        aa.append(i)

# %%
len(aa) #how many left as valid stocks in NYSE
# Out:
# 2255

# %%
# Create the pandas DataFrame NYSE 
df_nyse = pd.DataFrame(aa, columns = ['Stock Name']) # all valid stocks in this research in NYSE
  
# print dataframe. 
df_nyse
# Out:
#      Stock Name
# 0         "DDD"
# 1         "MMM"
# 2        "WBAI"
# 3        "WUBA"
# 4        "EGHT"
# 5         "AHC"
# 6         "AOS"
# 7        "ATEN"
# 8         "AIR"
# 9         "AAN"
# 10        "ABB"
# 11        "ABT"
# 12       "ABBV"
# 13        "ANF"
# 14        "AGD"
# 15        "AWP"
# 16        "ACP"
# 17        "JEQ"
# 18        "AOD"
# 19        "ABM"
# 20        "AKR"
# 21        "ACN"
# 22       "ACCO"
# 23        "ATV"
# 24        "AYI"
# 25        "ADX"
# 26        "PEO"
# 27       "AGRO"
# 28       "ATGE"
# 29        "AAP"
# ...         ...
# 2225      "WGO"
# 2226      "WIT"
# 2227      "WNS"
# 2228      "WWW"
# 2229       "WF"
# 2230       "WK"
# 2231      "INT"
# 2232      "WWE"
# 2233      "WOR"
# 2234      "WPP"
# 2235      "WPX"
# 2236     "WYND"
# 2237      "XHR"
# 2238      "XRX"
# 2239      "XIN"
# 2240      "XPO"
# 2241      "XYL"
# 2242      "AUY"
# 2243     "YELP"
# 2244     "YETI"
# 2245      "YRD"
# 2246      "DAO"
# 2247      "YPF"
# ...

# %%
#What stocks are there in NASDAQ? load all data from NASDAQ.csv into numpy array and list
with open ("data/NASDAQ.csv") as f:
    lines=f.readlines()
    symbol_na=[]
    row=len(lines)-1
    for i in range(row):
        tmp=lines[i+1].split(',')
        symbol_na.append(tmp[0])
print(symbol_na)
# Out:
# ['"TXG"', '"YI"', '"PIH"', '"PIHPP"', '"TURN"', '"FLWS"', '"BCOW"', '"FCCY"', '"SRCE"', '"VNET"', '"TWOU"', '"QFIN"', '"KRKR"', '"JOBS"', '"ETNB"', '"JFK"', '"JFKKR"', '"JFKKU"', '"JFKKW"', '"EGHT"', '"JFU"', '"AAON"', '"ABEO"', '"ABEOW"', '"ABIL"', '"ABMD"', '"AXAS"', '"ACIU"', '"ACIA"', '"ACTG"', '"ACHC"', '"ACAD"', '"ACAM"', '"ACAMU"', '"ACAMW"', '"ACST"', '"AXDX"', '"XLRN"', '"ARAY"', '"ACRX"', '"ACER"', '"ACHV"', '"ACHN"', '"ACIW"', '"ACRS"', '"ACMR"', '"ACNB"', '"ACOR"', '"ACTT"', '"ACTTU"', '"ACTTW"', '"ATVI"', '"ADMS"', '"ADMP"', '"AHCO"', '"AHCOW"', '"ADAP"', '"ADPT"', '"ADUS"', '"AEY"', '"IOTS"', '"ADIL"', '"ADILW"', '"ADMA"', '"ADBE"', '"ADTN"', '"ADRO"', '"ADES"', '"AEIS"', '"AMD"', '"ADXS"', '"ADVM"', '"DWMC"', '"DWSH"', '"ACT"', '"AEGN"', '"AGLE"', '"AEHR"', '"AMTX"', '"AERI"', '"AVAV"', '"ARPO"', '"AIH"', '"AEZS"', '"AEMD"', '"GNMX"', '"AFMD"', '"AFYA"', '"AGBA"', '"AGBAR"', '"AGBAU"', '"AGBAW"', '"AGEN"', '"AGRX"', '"AGYS"', '"AGIO"', '"AGMH"', '"AGNC"', '"AGNCB"', '"
# ...

# %%
len(symbol_na)
# Out:
# 3538

# %%
#downloading stocks through API in NASDAQ

from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
import time

count=0
count_time=time.time()
conflict=0
for i in symbol_na:
    print(str(count/3130*100)+'%')
    try:
        ts = TimeSeries(key='9QU5M7SRCS3PJ0ES',output_format='pandas')
        data, meta_data = ts.get_daily(symbol=i[1:-1], outputsize='full')
        data.to_csv(i[1:-1]+'.csv')
    except:
        print('error for ',i)
   # data.plot()
 #   plt.show()
    count+=1
    while((time.time()-count_time)<2):
        time.sleep(1)
    count_time=time.time()
# Out:
# 0.0%
# 0.03194888178913738%
# 0.06389776357827476%
# error for  "PIH"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-207-604ce8db75e9> in <module>()
#      20     count+=1
#      21     while((time.time()-count_time)<2):
# ---> 22         time.sleep(1)
#      23     count_time=time.time()
#
# KeyboardInterrupt:

# %%
available=[]

for i in symbol_na: # what nasdaq.csv does not have 
    try:
        tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
        available.append(i)
    except:
        print(r'does not have {0}'.format(i))

count_nasdaq=len(available)  # how many NASDAQ stocks downloaded
# Out:
# does not have "AGNCO"
# does not have "AFINP"
# does not have "RILYP"
# does not have "ZTEST"
# does not have "BLIN          "
# does not have "AVGOP"
# does not have "CARE"
# does not have "CATS"
# does not have "CBAT"
# does not have "CREX"
# does not have "EXPCW"
# does not have "FITBO"
# does not have "FRHC"
# does not have "GOODN"
# does not have "IHRT"
# does not have "INFN"
# does not have "INFI"
# does not have "IFRX"
# does not have "III"
# does not have "IEA"
# does not have "BSMO"
# does not have "BSMS"
# does not have "PRN"
# does not have "MESO"
# does not have "MNPR"
# does not have "NEWTI"
# does not have "OCCIP"
# does not have "PKOH"
# does not have "PHUN"
# does not have "RLMD"
# does not have "TXMD"
# does not have "VIAB"
# does not have "VSAT"
# does not have "VIAV"
# does not have "VICR"
# does not have "CEY"
# does not have "CEZ"
# does not have "CID"
# does not have "CFO"
# does not have "CDL"
# does not have "CSA"
# does not have "VMD"
# does not have "VLGEA"
# ...

# %%
print(count_nasdaq)
# Out:
# 3491

# %%
len(available)
# Out:
# 3491

# %%
date1=pd.to_datetime('2016-06-28')# which stock was registered before 6.28.2016 and closed after 10.10.2019 in NASDAQ
date31=pd.to_datetime('2019-10-10')
a=[]
for i in available: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    if (date1 > dates[0]) and (date31 < dates[len(dates)-1]):
        a.append(i)

# %%
len(a)
# Out:
# 2524

# %%
joinlist = a + aa

# %%
len(joinlist)
# Out:
# 4779

# %%
# Create the pandas NASDAQ DataFrame 
df_nasdaq = pd.DataFrame(a, columns = ['Stock Name']) # all valid stocks in this research 
  
# print NASDAQ dataframe. 
df_nasdaq
# Out:
#      Stock Name
# 0         "PIH"
# 1        "FLWS"
# 2        "SRCE"
# 3        "VNET"
# 4        "TWOU"
# 5        "JOBS"
# 6        "EGHT"
# 7        "AAON"
# 8        "ABEO"
# 9        "ABIL"
# 10       "ABMD"
# 11       "AXAS"
# 12       "ACIA"
# 13       "ACTG"
# 14       "ACHC"
# 15       "ACAD"
# 16       "ACST"
# 17       "AXDX"
# 18       "XLRN"
# 19       "ARAY"
# 20       "ACRX"
# 21       "ACER"
# 22       "ACHV"
# 23       "ACHN"
# 24       "ACIW"
# 25       "ACRS"
# 26       "ACNB"
# 27       "ACOR"
# 28       "ATVI"
# 29       "ADMS"
# ...         ...
# 2494      "XEL"
# 2495     "XNCR"
# 2496     "XENE"
# 2497     "XLNX"
# 2498     "XOMA"
# 2499     "XPER"
# 2500     "XSPA"
# 2501     "XTLB"
# 2502     "XNET"
# 2503     "YNDX"
# 2504     "YTEN"
# 2505      "YIN"
# 2506     "YGYI"
# 2507     "YRCW"
# 2508       "YY"
# 2509     "ZFGN"
# 2510     "ZAGG"
# 2511     "ZBRA"
# 2512        "Z"
# 2513       "ZG"
# 2514       "ZN"
# 2515     "ZION"
# 2516     "ZIOP"
# ...

# %%
# Create the pandas DataFrame 
df = pd.DataFrame(joinlist, columns = ['Stock Name']) # all valid stocks in this research 
  
# print dataframe. 
df
# Out:
#      Stock Name
# 0         "PIH"
# 1        "FLWS"
# 2        "SRCE"
# 3        "VNET"
# 4        "TWOU"
# 5        "JOBS"
# 6        "EGHT"
# 7        "AAON"
# 8        "ABEO"
# 9        "ABIL"
# 10       "ABMD"
# 11       "AXAS"
# 12       "ACIA"
# 13       "ACTG"
# 14       "ACHC"
# 15       "ACAD"
# 16       "ACST"
# 17       "AXDX"
# 18       "XLRN"
# 19       "ARAY"
# 20       "ACRX"
# 21       "ACER"
# 22       "ACHV"
# 23       "ACHN"
# 24       "ACIW"
# 25       "ACRS"
# 26       "ACNB"
# 27       "ACOR"
# 28       "ATVI"
# 29       "ADMS"
# ...         ...
# 4749      "WGO"
# 4750      "WIT"
# 4751      "WNS"
# 4752      "WWW"
# 4753       "WF"
# 4754       "WK"
# 4755      "INT"
# 4756      "WWE"
# 4757      "WOR"
# 4758      "WPP"
# 4759      "WPX"
# 4760     "WYND"
# 4761      "XHR"
# 4762      "XRX"
# 4763      "XIN"
# 4764      "XPO"
# 4765      "XYL"
# 4766      "AUY"
# 4767     "YELP"
# 4768     "YETI"
# 4769      "YRD"
# 4770      "DAO"
# 4771      "YPF"
# ...

# %%
df.to_csv('validstocks.csv')

# %%
# 1st important date: 6/28/2016    S&P 500: +1.78%

date1=pd.to_datetime('2016-06-28') # which stock has price on 6/28/2018 in NASDAQ
a1=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date1:
                price=tmp['4. close'][j] #6.28
                price1=tmp['4. close'][j-1] #6.27
                b=[i,price1,price]
                a1.append(b)
                break

# %%
len(a1)
# Out:
# 4779

# %%
df1 = pd.DataFrame(a1, columns = ['Stock Name','Price 6/27/2016','Price 6/28/2016']) 
df1
# Out:
#      Stock Name  Price 6/27/2016  Price 6/28/2016
# 0         "PIH"            6.530           6.4628
# 1        "FLWS"            8.190           8.4100
# 2        "SRCE"           30.740          31.0500
# 3        "VNET"            9.830          10.5000
# 4        "TWOU"           27.610          28.5300
# 5        "JOBS"           28.460          29.1200
# 6        "EGHT"           13.360          13.6600
# 7        "AAON"           26.190          25.9300
# 8        "ABEO"            2.440           2.4300
# 9        "ABIL"            3.860           4.0300
# 10       "ABMD"          101.230         105.0900
# 11       "AXAS"            1.050           1.0900
# 12       "ACIA"           34.450          38.1900
# 13       "ACTG"            4.210           4.1300
# 14       "ACHC"           51.030          53.3200
# 15       "ACAD"           30.300          31.6600
# 16       "ACST"            1.370           1.3990
# 17       "AXDX"           14.430          14.2200
# ...

# %%
df1.to_csv('06282016.csv')

# %%
# 2rd important date: 3/31/2017    S&P 500: -0.23%

date2=pd.to_datetime('2017-03-31') # which stock has price on 3/31/2017 in NASDAQ
a2=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date2:
                price=tmp['4. close'][j] #3.31.2017
                price1=tmp['4. close'][j-1] #3.30.2017
                b=[i,price1,price]
                a2.append(b)
                break

# %%
len(a2)
# Out:
# 4779

# %%
df2 = pd.DataFrame(a2, columns = ['Stock Name','Price 3/30/2017','Price 3/31/2017']) 
df2
# Out:
#      Stock Name  Price 3/30/2017  Price 3/31/2017
# 0         "PIH"            7.900            8.100
# 1        "FLWS"           10.250           10.200
# 2        "SRCE"           47.010           46.950
# 3        "VNET"            5.610            5.490
# 4        "TWOU"           38.710           39.660
# 5        "JOBS"           36.260           36.660
# 6        "EGHT"           15.250           15.250
# 7        "AAON"           35.250           35.350
# 8        "ABEO"            5.000            5.000
# 9        "ABIL"            2.080            1.980
# 10       "ABMD"          125.000          125.200
# 11       "AXAS"            1.940            2.020
# 12       "ACIA"           57.860           58.620
# 13       "ACTG"            5.550            5.750
# 14       "ACHC"           43.780           43.600
# 15       "ACAD"           34.100           34.380
# 16       "ACST"            1.320            1.360
# 17       "AXDX"           24.100           24.200
# ...

# %%
df2.to_csv('03312017.csv')

# %%
# 3rd important date: 4/7/2017    S&P 500: -0.08%

date3=pd.to_datetime('2017-04-07') # which stock has price on 4/7/2017 in NASDAQ
a3=[]
for i in joinlist: 
    tmp=pd.read_csv(i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date3:
                price2=tmp['4. close'][j] #4.7.2017
                price1=tmp['4. close'][j-1] #4.6.2017
                b=[i,price1,price2]
                a3.append(b)
                break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-83-191983be2de6> in <module>()
#       4 a3=[]
#       5 for i in joinlist:
# ----> 6     tmp=pd.read_csv(i[1:-1]+'.csv')
#       7     dates=pd.to_datetime(tmp['date'])
#       8     for j in range(len(dates)):
#
# ...

# %%
len(a3)
# Out:
# 4779

# %%
df3 = pd.DataFrame(a3, columns = ['Stock Name','Price 4/6/2017','Price 4/7/2017']) 
df3
# Out:
#      Stock Name  Price 4/6/2017  Price 4/7/2017
# 0         "PIH"           7.700           7.695
# 1        "FLWS"          10.050          10.200
# 2        "SRCE"          46.510          45.910
# 3        "VNET"           5.480           5.390
# 4        "TWOU"          40.810          41.540
# 5        "JOBS"          38.590          38.960
# 6        "EGHT"          15.200          15.200
# 7        "AAON"          34.400          34.300
# 8        "ABEO"           5.150           5.050
# 9        "ABIL"           1.780           1.769
# 10       "ABMD"         125.540         125.490
# 11       "AXAS"           2.240           2.200
# 12       "ACIA"          57.030          56.000
# 13       "ACTG"           5.400           5.550
# 14       "ACHC"          43.970          43.460
# 15       "ACAD"          32.410          32.360
# 16       "ACST"           1.330           1.330
# 17       "AXDX"          25.050          24.750
# 18       "XLRN"          26.010          26.450
# ...

# %%
df3.to_csv('04072017.csv')

# %%
# 4th important date: 07/19/2017 Wednesday     S&P 500: +0.54%
date4=pd.to_datetime('2017-07-19') # which stock has price on 7/19/2017 in NASDAQ
a4=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date4:
                price2=tmp['4. close'][j] #7.19.2017
                price1=tmp['4. close'][j-1] #7.18.2017
                b=[i,price1,price2]
                a4.append(b)
                break

# %%
len(a4)
# Out:
# 4779

# %%
df4 = pd.DataFrame(a4, columns = ['Stock Name','Price 07/18/2017','Price 7/19/2017']) 
df4
# Out:
#      Stock Name  Price 07/18/2017  Price 7/19/2017
# 0         "PIH"             7.800            7.900
# 1        "FLWS"             9.600            9.650
# 2        "SRCE"            48.990           48.670
# 3        "VNET"             4.600            4.590
# 4        "TWOU"            48.840           49.730
# 5        "JOBS"            47.870           47.840
# 6        "EGHT"            14.150           13.550
# 7        "AAON"            37.150           37.550
# 8        "ABEO"             8.950            9.850
# 9        "ABIL"             1.040            0.960
# 10       "ABMD"           144.340          144.550
# 11       "AXAS"             1.590            1.670
# 12       "ACIA"            39.610           42.490
# 13       "ACTG"             4.000            4.150
# 14       "ACHC"            49.840           50.430
# 15       "ACAD"            28.960           29.000
# 16       "ACST"             1.300            1.280
# ...

# %%
df4.to_csv('07192017.csv')

# %%
# 4th important date: 07/19/2017 Wednesday     S&P 500: +0.54%


#Aug. 14, 2017       S&P 500: +1.00%
date5=pd.to_datetime('2017-08-14') 

#Jan. 17, 2018       S&P 500: +0.94%
date6=pd.to_datetime('2018-01-17')

#Jan. 22, 2018       S&P 500: +0.81%
date7=pd.to_datetime('2018-01-22')

#March 8, 2018       S&P 500: +0.45%
date8=pd.to_datetime('2018-03-08')

#April 2, 2018       S&P 500: -2.23%
date9=pd.to_datetime('2018-04-02')

#April 3, 2018       S&P 500: +1.26%
date10=pd.to_datetime('2018-04-03')

#April 4, 2018       S&P 500: +1.16%
date11=pd.to_datetime('2018-04-04')

#June 15, 2018       S&P 500: -0.10%
date12=pd.to_datetime('2018-06-15')

#July 10, 2018       S&P 500: +0.35%
date13=pd.to_datetime('2018-07-10')

#Aug. 1, 2018        S&P 500: -0.10%
date14=pd.to_datetime('2018-08-01')

#Aug. 7, 2018        S&P 500: +0.28%
date15=pd.to_datetime('2018-08-07')

#Aug. 23, 2018       S&P 500: -0.17%
date16=pd.to_datetime('2018-08-23')

#Sept. 7, 2018       S&P 500: -0.22%
date17=pd.to_datetime('2018-09-07')

#Sept. 24, 2018      S&P 500: -0.35%
date18=pd.to_datetime('2018-09-24')

#Dec. 1, 2018        S&P 500: +1.09% 
date19=pd.to_datetime('2018-12-01')

#Feb. 24, 2019       S&P 500: +0.12% (Monday, Feb 25)
date20=pd.to_datetime('2019-02-24')

#May 5, 2019         S&P 500: -0.45% (Monday, May 6)
date21=pd.to_datetime('2019-05-05')

#May 8, 2019         S&P 500: -0.16%
date22=pd.to_datetime('2019-05-08')

#June 18, 2019       S&P 500: +0.97%
date23=pd.to_datetime('2019-06-18')

#June 29, 2019       S&P 500: +0.77% (Monday, July 1)
date24=pd.to_datetime('2019-06-29')

#Aug. 1, 2019        S&P 500: -0.90%
date25=pd.to_datetime('2019-08-01')

#Aug. 13, 2019       S&P500:   +1.5%
date26=pd.to_datetime('2019-08-13')

#Aug. 23, 2019       S&P 500: -0.1%
date27=pd.to_datetime('2019-08-23')

#Sept. 20, 2019      S&P 500: -0.53%
date28=pd.to_datetime('2019-09-20')

#Sept. 23, 2019      S&P 500: -0.01%
date29=pd.to_datetime('2019-09-23')

#Oct. 7, 2019        S&P 500: -0.46%
date30=pd.to_datetime('2019-10-07')

#Oct. 10, 2019       S&P 500 open: -0.066%
date31=pd.to_datetime('2019-10-10')


a4=[]
a5=[]
a6=[]
a7=[]
a8=[]
a9=[]
a10=[]
a11=[]
a12=[]
a13=[]
a14=[]
a15=[]
a16=[]
a17=[]
a18=[]
a19=[]
a20=[]
a21=[]
a22=[]
a23=[]
a24=[]
a25=[]
a26=[]
a27=[]
a28=[]
a29=[]
a30=[]
a31=[]


for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date5:
                price2=tmp['4. close'][j] #8.14.2017
                price1=tmp['4. close'][j-1] #8.13.2017
                b=[i,price1,price2]
                a5.append(b)
                break

# %%
len(a5)
# Out:
# 4779

# %%
df5 = pd.DataFrame(a5, columns = ['Stock Name','Price 08/13/2017','Price 8/14/2017']) 
df5.to_csv('08142017.csv')

# %%
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date6:
                price2=tmp['4. close'][j]  #1. 17, 2018 
                price1=tmp['4. close'][j-1]  #1.16.2018
                b=[i,price1,price2]
                a6.append(b)
                break

# %%
len(a6)
# Out:
# 4779

# %%
df6 = pd.DataFrame(a6, columns = ['Stock Name','Price 01/16/2018','Price 01/17/2018']) 
df6.to_csv('01172018.csv')

# %%
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date7:
                price2=tmp['4. close'][j]  #1.22.2018 
                price1=tmp['4. close'][j-1]  #1.21.2018
                b=[i,price1,price2]
                a7.append(b)
                break

# %%
len(a7)
# Out:
# 4779

# %%
df7 = pd.DataFrame(a7, columns = ['Stock Name','Price 01/21/2018','Price 01/22/2018']) 
df7.to_csv('01222018.csv')

# %%
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date8:
                price2=tmp['4. close'][j]  #3.8.2018 
                price1=tmp['4. close'][j-1]  #3.7.2018
                b=[i,price1,price2]
                a8.append(b)
                break

# %%
len(a8)
# Out:
# 4779

# %%
df8 = pd.DataFrame(a8, columns = ['Stock Name','Price 03/07/2018','Price 03/08/2018']) 
df8.to_csv('03082018.csv')

# %%
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date9:
                price2=tmp['4. close'][j]  #4.2.2018 
                price1=tmp['4. close'][j-1]  #4.1.2018
                b=[i,price1,price2]
                a9.append(b)
                break

# %%
len(a9)
# Out:
# 4779

# %%
df9 = pd.DataFrame(a9, columns = ['Stock Name','Price 04/01/2018','Price 04/02/2018']) 
df9.to_csv('04022018.csv')

# %%
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date10:
                price2=tmp['4. close'][j]  #4.3.2018 
                price1=tmp['4. close'][j-1]  #4.2.2018
                b=[i,price1,price2]
                a10.append(b)
                break

# %%
len(a10)
# Out:
# 4779

# %%
df10 = pd.DataFrame(a10, columns = ['Stock Name','Price 04/02/2018','Price 04/03/2018']) 
df10.to_csv('04032018.csv')

# %%
a11=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date11:
                price2=tmp['4. close'][j]  #4.4.2018
                price1=tmp['4. close'][j-1]  #4.3.2018
                b=[i,price1,price2]
                a11.append(b)
                break

# %%
len(a11)
# Out:
# 4779

# %%
df11 = pd.DataFrame(a11, columns = ['Stock Name','Price 04/03/2018','Price 04/04/2018']) 
df11.to_csv('04042018.csv')

# %%
a12=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date12:
                price2=tmp['4. close'][j]  #6.15.2018
                price1=tmp['4. close'][j-1]  #6.14.2018
                b=[i,price1,price2]
                a12.append(b)
                break

# %%
len(a12)
# Out:
# 4779

# %%
df12 = pd.DataFrame(a12, columns = ['Stock Name','Price 06/14/2018','Price 06/15/2018']) 
df12.to_csv('06152018.csv')

# %%
#July 10, 2018       S&P 500: +0.35%
date13=pd.to_datetime('2018-07-10')

#Aug. 1, 2018        S&P 500: -0.10%
date14=pd.to_datetime('2018-08-01')

#Aug. 7, 2018        S&P 500: +0.28%
date15=pd.to_datetime('2018-08-07')

#Aug. 23, 2018       S&P 500: -0.17%
date16=pd.to_datetime('2018-08-23')

#Sept. 7, 2018       S&P 500: -0.22%
date17=pd.to_datetime('2018-09-07')

#Sept. 24, 2018      S&P 500: -0.35%
date18=pd.to_datetime('2018-09-24')

#Dec. 1, 2018        S&P 500: +1.09% 
date19=pd.to_datetime('2018-12-01')

#Feb. 24, 2019       S&P 500: +0.12% (Monday, Feb 25)
date20=pd.to_datetime('2019-02-24')

#May 5, 2019         S&P 500: -0.45% (Monday, May 6)
date21=pd.to_datetime('2019-05-05')

#May 8, 2019         S&P 500: -0.16%
date22=pd.to_datetime('2019-05-08')

#June 18, 2019       S&P 500: +0.97%
date23=pd.to_datetime('2019-06-18')

#June 29, 2019       S&P 500: +0.77% (Monday, July 1)
date24=pd.to_datetime('2019-06-29')

#Aug. 1, 2019        S&P 500: -0.90%
date25=pd.to_datetime('2019-08-01')

#Aug. 13, 2019       S&P500:   +1.5%
date26=pd.to_datetime('2019-08-13')

#Aug. 23, 2019       S&P 500: -0.1%
date27=pd.to_datetime('2019-08-23')

#Sept. 20, 2019      S&P 500: -0.53%
date28=pd.to_datetime('2019-09-20')

#Sept. 23, 2019      S&P 500: -0.01%
date29=pd.to_datetime('2019-09-23')

#Oct. 7, 2019        S&P 500: -0.46%
date30=pd.to_datetime('2019-10-07')

#Oct. 10, 2019       S&P 500 open: -0.066%
date31=pd.to_datetime('2019-10-10')



a13=[]
a14=[]
a15=[]
a16=[]
a17=[]
a18=[]
a19=[]
a20=[]
a21=[]
a22=[]
a23=[]
a24=[]
a25=[]
a26=[]
a27=[]
a28=[]
a29=[]
a30=[]
a31=[]

# %%
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date13:
                price2=tmp['4. close'][j]  #7.10.2018
                price1=tmp['4. close'][j-1]  #7.09.2018
                b=[i,price1,price2]
                a13.append(b)
                break

# %%
len(a13)
# Out:
# 4779

# %%
df13 = pd.DataFrame(a13, columns = ['Stock Name','Price 07/09/2018','Price 07/10/2018']) 
df13.to_csv('07102018.csv')

# %%
#Aug. 1, 2018        S&P 500: -0.10%
date14=pd.to_datetime('2018-08-01')

# %%
a14=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date14:
                price2=tmp['4. close'][j]  #8.1.2018
                price1=tmp['4. close'][j-1]  #7.31.2018
                b=[i,price1,price2]
                a14.append(b)
                break

# %%
len(a14)
# Out:
# 4779

# %%
df14 = pd.DataFrame(a14, columns = ['Stock Name','Price 07/31/2018','Price 08/01/2018']) 
df14.to_csv('08012018.csv')

# %%
df14
# Out:
#      Stock Name  Price 07/31/2018  Price 08/01/2018
# 0         "PIH"             7.150            7.0619
# 1        "FLWS"            14.500           14.3000
# 2        "SRCE"            56.560           56.6600
# 3        "VNET"             9.440            8.8900
# 4        "TWOU"            75.660           76.8100
# 5        "JOBS"            91.770           92.8200
# 6        "EGHT"            19.950           20.1000
# 7        "AAON"            37.750           37.5000
# 8        "ABEO"            14.450           14.4500
# 9        "ABIL"             3.255            3.0500
# 10       "ABMD"           354.530          363.1900
# 11       "AXAS"             2.600            2.4500
# 12       "ACIA"            32.140           32.4100
# 13       "ACTG"             3.800            3.8000
# 14       "ACHC"            39.480           40.3750
# 15       "ACAD"            15.090           15.3600
# 16       "ACST"             0.587            0.5720
# ...

# %%
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date15:
                price2=tmp['4. close'][j]  #8.7.2018
                price1=tmp['4. close'][j-1]  #8.6.2018
                b=[i,price1,price2]
                a15.append(b)
                break

# %%
len(a15)
# Out:
# 4779

# %%
df15 = pd.DataFrame(a15, columns = ['Stock Name','Price 08/07/2018','Price 08/06/2018']) 
df15.to_csv('08012018.csv')

# %%
#Aug. 23, 2018       S&P 500: -0.17%
date16=pd.to_datetime('2018-08-23')

# %%
a16=[] #Aug. 23, 2018 
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date16:
                price2=tmp['4. close'][j]  #8.23.2018
                price1=tmp['4. close'][j-1]  #8.22.2018
                b=[i,price1,price2]
                a16.append(b)
                break

# %%
len(a16)
# Out:
# 4779

# %%
df16 = pd.DataFrame(a16, columns = ['Stock Name','Price 08/22/2018','Price 08/23/2018']) 
df16.to_csv('08232018.csv')

# %%
#Sept. 7, 2018       S&P 500: -0.22%
date17=pd.to_datetime('2018-09-07')

#Sept. 24, 2018      S&P 500: -0.35%
date18=pd.to_datetime('2018-09-24')

#Dec. 1, 2018        S&P 500: +1.09% 
date19=pd.to_datetime('2018-12-01')

#Feb. 24, 2019       S&P 500: +0.12% (Monday, Feb 25)
date20=pd.to_datetime('2019-02-24')

#May 5, 2019         S&P 500: -0.45% (Monday, May 6)
date21=pd.to_datetime('2019-05-05')

#May 8, 2019         S&P 500: -0.16%
date22=pd.to_datetime('2019-05-08')

#June 18, 2019       S&P 500: +0.97%
date23=pd.to_datetime('2019-06-18')

# %%
a17=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date17:
                price2=tmp['4. close'][j]  #9.7.2018
                price1=tmp['4. close'][j-1]  #9.6.2018
                b=[i,price1,price2]
                a17.append(b)
                break

# %%
len(a17)
# Out:
# 4779

# %%
df17 = pd.DataFrame(a17, columns = ['Stock Name','Price 09/06/2018','Price 09/07/2018']) 
df17
# Out:
#      Stock Name  Price 09/06/2018  Price 09/07/2018
# 0         "PIH"              6.80             6.850
# 1        "FLWS"             11.90            12.300
# 2        "SRCE"             55.92            56.140
# 3        "VNET"              9.66             9.740
# 4        "TWOU"             83.28            84.030
# 5        "JOBS"             72.11            72.510
# 6        "EGHT"             22.65            22.700
# 7        "AAON"             39.75            39.400
# 8        "ABEO"             13.70            13.650
# 9        "ABIL"              3.48             3.410
# 10       "ABMD"            383.10           377.490
# 11       "AXAS"              2.13             2.150
# 12       "ACIA"             39.75            39.710
# 13       "ACTG"              3.35             3.500
# 14       "ACHC"             39.88            38.890
# 15       "ACAD"             14.03            14.040
# 16       "ACST"              0.58             0.594
# ...

# %%
df17.to_csv('09072018.csv')

# %%
a18=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date18:
                price2=tmp['4. close'][j]  #9.24.2018 
                price1=tmp['4. close'][j-1]  #9.23.2018
                b=[i,price1,price2]
                a18.append(b)
                break

# %%
len(a18)
# Out:
# 4779

# %%
df18 = pd.DataFrame(a18, columns = ['Stock Name','Price 09/23/2018','Price 09/24/2018']) 
df18
# Out:
#      Stock Name  Price 09/23/2018  Price 09/24/2018
# 0         "PIH"             6.900             6.550
# 1        "FLWS"            11.950            11.600
# 2        "SRCE"            54.310            53.600
# 3        "VNET"            10.380            10.040
# 4        "TWOU"            76.340            77.010
# 5        "JOBS"            75.240            74.020
# 6        "EGHT"            21.200            21.450
# 7        "AAON"            39.850            39.300
# 8        "ABEO"            12.625            13.725
# 9        "ABIL"             4.400             4.150
# 10       "ABMD"           384.880           419.610
# 11       "AXAS"             2.400             2.480
# 12       "ACIA"            39.790            40.260
# 13       "ACTG"             3.300             3.150
# 14       "ACHC"            35.690            36.000
# 15       "ACAD"            20.170            19.850
# 16       "ACST"             0.589             0.835
# ...

# %%
df18.to_csv('09242018.csv')

# %%
a19=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date19:
                price2=tmp['4. close'][j]  #12.1.2018 
                price1=tmp['4. close'][j-1]  #11.30.2018
                b=[i,price1,price2]
                a19.append(b)
                break

# %%
len(a19)
# Out:
# 4779

# %%
df19 = pd.DataFrame(a19, columns = ['Stock Name','Price 11/30/2018','Price 12/01/2018']) 
df19
# Out:
#      Stock Name  Price 11/30/2018  Price 12/01/2018
# 0         "PIH"             5.010             5.000
# 1        "FLWS"            12.510            12.600
# 2        "SRCE"            48.360            48.270
# 3        "VNET"             9.480             9.980
# 4        "TWOU"            58.390            57.350
# 5        "JOBS"            68.080            72.310
# 6        "EGHT"            19.710            20.200
# 7        "AAON"            37.950            38.790
# 8        "ABEO"             8.200             8.500
# 9        "ABIL"             2.690             2.620
# 10       "ABMD"           332.680           343.450
# 11       "AXAS"             1.630             1.840
# 12       "ACIA"            42.880            43.670
# 13       "ACTG"             3.180             3.180
# 14       "ACHC"            33.970            33.890
# 15       "ACAD"            19.060            20.300
# 16       "ACST"             0.730             0.700
# ...

# %%
df19.to_csv('12012018.csv')

# %%
#Feb. 24, 2019       S&P 500: +0.12% (Monday, Feb 25)
date20=pd.to_datetime('2019-02-24')
a20=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date20:
                price2=tmp['4. close'][j]  #2.24.2019 
                price1=tmp['4. close'][j-1]  #2.23.2019
                b=[i,price1,price2]
                a20.append(b)
                break

# %%
len(a20)
# Out:
# 4779

# %%
df20 = pd.DataFrame(a20, columns = ['Stock Name','Price 02/23/2019','Price 02/24/2019']) 
df20
# Out:
#      Stock Name  Price 02/23/2019  Price 02/24/2019
# 0         "PIH"            4.5728              4.80
# 1        "FLWS"           17.6800             17.98
# 2        "SRCE"           47.6500             47.54
# 3        "VNET"            9.4100              9.91
# 4        "TWOU"           70.0800             71.20
# 5        "JOBS"           71.6200             74.07
# 6        "EGHT"           20.0800             20.10
# 7        "AAON"           42.1800             42.28
# 8        "ABEO"            6.4700              7.33
# 9        "ABIL"            1.8800              1.87
# 10       "ABMD"          352.6000            352.89
# 11       "AXAS"            1.3900              1.32
# 12       "ACIA"           55.4500             56.46
# 13       "ACTG"            3.2000              3.16
# 14       "ACHC"           27.7000             27.85
# 15       "ACAD"           22.9300             23.75
# 16       "ACST"            1.0100              1.08
# ...

# %%
df20.to_csv('02242019.csv')

# %%
a21=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date21:
                price2=tmp['4. close'][j]  #5.5.2019 
                price1=tmp['4. close'][j-1]  #5.4.2019
                b=[i,price1,price2]
                a21.append(b)
                break

# %%
len(a21)
# Out:
# 4779

# %%
df21 = pd.DataFrame(a21, columns = ['Stock Name','Price 05/04/2019','Price 05/05/2019']) 
df21
# Out:
#      Stock Name  Price 05/04/2019  Price 05/05/2019
# 0         "PIH"            5.0332              5.00
# 1        "FLWS"           20.4900             20.31
# 2        "SRCE"           48.5500             48.52
# 3        "VNET"            7.8100              7.76
# 4        "TWOU"           62.4700             62.39
# 5        "JOBS"           94.4000             91.90
# 6        "EGHT"           24.2100             24.21
# 7        "AAON"           51.8100             49.35
# 8        "ABEO"            7.8200              8.02
# 9        "ABIL"            1.3700              1.40
# 10       "ABMD"          271.7500            268.95
# 11       "AXAS"            1.3500              1.35
# 12       "ACIA"           59.0000             55.78
# 13       "ACTG"            3.1600              3.13
# 14       "ACHC"           33.4200             33.82
# 15       "ACAD"           26.5200             26.79
# 16       "ACST"            0.8500              0.84
# ...

# %%
df21.to_csv('05052019.csv')

# %%
#May 8, 2019         S&P 500: -0.16%
date22=pd.to_datetime('2019-05-08')
a22=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date22:
                price2=tmp['4. close'][j]  #5.8.2019 
                price1=tmp['4. close'][j-1]  #5.7.2019
                b=[i,price1,price2]
                a22.append(b)
                break

# %%
len(a22)
# Out:
# 4779

# %%
df22 = pd.DataFrame(a22, columns = ['Stock Name','Price 05/07/2019','Price 05/08/2019']) 
df22
# Out:
#      Stock Name  Price 05/07/2019  Price 05/08/2019
# 0         "PIH"              5.04            5.0049
# 1        "FLWS"             20.43           20.1500
# 2        "SRCE"             48.04           47.3600
# 3        "VNET"              7.64            7.7700
# 4        "TWOU"             59.93           44.7700
# 5        "JOBS"             88.25           86.5500
# 6        "EGHT"             23.65           24.0100
# 7        "AAON"             47.38           47.3500
# 8        "ABEO"              7.86            7.8700
# 9        "ABIL"              1.39            1.4500
# 10       "ABMD"            261.98          260.2700
# 11       "AXAS"              1.30            1.2500
# 12       "ACIA"             54.27           54.9800
# 13       "ACTG"              3.12            3.1400
# 14       "ACHC"             32.60           32.5600
# 15       "ACAD"             25.81           26.1500
# 16       "ACST"              0.81            0.8000
# ...

# %%
df22.to_csv('222.csv')

# %%
a23=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date23:
                price2=tmp['4. close'][j]  #6.18.2019 
                price1=tmp['4. close'][j-1]  #6.17.2019
                b=[i,price1,price2]
                a23.append(b)
                break

# %%
len(a23)
# Out:
# 4779

# %%
df23 = pd.DataFrame(a23, columns = ['Stock Name','Price 06/17/2019','Price 06/18/2019']) 
df23
# Out:
#      Stock Name  Price 06/17/2019  Price 06/18/2019
# 0         "PIH"              5.60              5.60
# 1        "FLWS"             20.00             20.21
# 2        "SRCE"             44.58             45.25
# 3        "VNET"              7.19              7.54
# 4        "TWOU"             35.89             37.97
# 5        "JOBS"             70.21             73.69
# 6        "EGHT"             24.20             24.88
# 7        "AAON"             48.03             48.59
# 8        "ABEO"              5.37              5.01
# 9        "ABIL"              1.09              1.11
# 10       "ABMD"            256.15            256.47
# 11       "AXAS"              1.13              1.08
# 12       "ACIA"             44.79             46.53
# 13       "ACTG"              3.10              3.10
# 14       "ACHC"             34.00             34.20
# 15       "ACAD"             25.42             25.93
# 16       "ACST"              0.91              0.93
# ...

# %%
df23.to_csv('06182019.csv')

# %%
#June 29, 2019       S&P 500: +0.77% (Monday, July 1)
date24=pd.to_datetime('2019-06-29')

#Aug. 1, 2019        S&P 500: -0.90%
date25=pd.to_datetime('2019-08-01')

#Aug. 13, 2019       S&P500:   +1.5%
date26=pd.to_datetime('2019-08-13')

#Aug. 23, 2019       S&P 500: -0.1%
date27=pd.to_datetime('2019-08-23')

#Sept. 20, 2019      S&P 500: -0.53%
date28=pd.to_datetime('2019-09-20')

#Sept. 23, 2019      S&P 500: -0.01%
date29=pd.to_datetime('2019-09-23')

#Oct. 7, 2019        S&P 500: -0.46%
date30=pd.to_datetime('2019-10-07')

#Oct. 10, 2019       S&P 500 open: -0.066%
date31=pd.to_datetime('2019-10-10')

# %%
a24=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date24:
                price2=tmp['4. close'][j]  #6.29.2019 
                price1=tmp['4. close'][j-1]  #6.28.2019
                b=[i,price1,price2]
                a24.append(b)
                break

# %%
len(a24)
# Out:
# 4779

# %%
df24 = pd.DataFrame(a24, columns = ['Stock Name','Price 06/28/2019','Price 06/29/2019']) 
df24
# Out:
#      Stock Name  Price 06/28/2019  Price 06/29/2019
# 0         "PIH"              4.95             5.190
# 1        "FLWS"             18.88            19.310
# 2        "SRCE"             46.40            46.420
# 3        "VNET"              7.79             7.890
# 4        "TWOU"             37.64            38.640
# 5        "JOBS"             75.50            77.080
# 6        "EGHT"             24.10            24.420
# 7        "AAON"             50.18            49.730
# 8        "ABEO"              4.78             4.770
# 9        "ABIL"              0.92             0.922
# 10       "ABMD"            260.49           265.020
# 11       "AXAS"              1.03             1.090
# 12       "ACIA"             47.16            50.440
# 13       "ACTG"              2.96             2.900
# 14       "ACHC"             34.95            34.310
# 15       "ACAD"             26.73            26.920
# 16       "ACST"              1.14             1.160
# ...

# %%
df24.to_csv('06292019.csv')

# %%
a25=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date25:
                price2=tmp['4. close'][j]  # 8.1.2019
                price1=tmp['4. close'][j-1]  #7.31.2019
                b=[i,price1,price2]
                a25.append(b)
                break

# %%
len(a25)
# Out:
# 4779

# %%
df25 = pd.DataFrame(a25, columns = ['Stock Name','Price 07/31/2019','Price 08/01/2019']) 
df25
# Out:
#      Stock Name  Price 07/31/2019  Price 08/01/2019
# 0         "PIH"              5.05              5.07
# 1        "FLWS"             19.58             19.24
# 2        "SRCE"             46.95             46.00
# 3        "VNET"              7.36              7.24
# 4        "TWOU"             12.80             13.92
# 5        "JOBS"             77.55             75.55
# 6        "EGHT"             24.17             23.57
# 7        "AAON"             50.80             51.86
# 8        "ABEO"              2.59              2.52
# 9        "ABIL"              0.78              0.77
# 10       "ABMD"            278.56            204.87
# 11       "AXAS"              0.87              0.79
# 12       "ACIA"             67.17             66.22
# 13       "ACTG"              2.79              2.75
# 14       "ACHC"             31.94             29.64
# 15       "ACAD"             24.58             28.67
# 16       "ACST"              2.41              2.48
# ...

# %%
df25.to_csv('08012019.csv')

# %%
a26=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date26:
                price2=tmp['4. close'][j]  # 8.13.2019
                price1=tmp['4. close'][j-1]  #8.12.2019
                b=[i,price1,price2]
                a26.append(b)
                break

# %%
len(a26)
# Out:
# 4779

# %%
df26 = pd.DataFrame(a26, columns = ['Stock Name','Price 08/12/2019','Price 08/13/2019']) 
df26
# Out:
#      Stock Name  Price 08/12/2019  Price 08/13/2019
# 0         "PIH"             5.230             5.180
# 1        "FLWS"            18.700            19.240
# 2        "SRCE"            44.700            44.950
# 3        "VNET"             7.020             7.230
# 4        "TWOU"            14.980            16.010
# 5        "JOBS"            62.350            64.360
# 6        "EGHT"            24.850            25.250
# 7        "AAON"            43.820            44.950
# 8        "ABEO"             2.280             2.390
# 9        "ABIL"             0.620             0.670
# 10       "ABMD"           191.720           197.150
# 11       "AXAS"             0.621             0.604
# 12       "ACIA"            63.540            65.050
# 13       "ACTG"             2.940             2.950
# 14       "ACHC"            28.260            29.020
# 15       "ACAD"            29.720            29.450
# 16       "ACST"             1.950             1.930
# ...

# %%
df26.to_csv('080132019.csv')

# %%
#Aug. 23, 2019       S&P 500: -0.1%
date27=pd.to_datetime('2019-08-23')

#Sept. 20, 2019      S&P 500: -0.53%
date28=pd.to_datetime('2019-09-20')

#Sept. 23, 2019      S&P 500: -0.01%
date29=pd.to_datetime('2019-09-23')

#Oct. 7, 2019        S&P 500: -0.46%
date30=pd.to_datetime('2019-10-07')

#Oct. 10, 2019       S&P 500 open: -0.066%
date31=pd.to_datetime('2019-10-10')

# %%
a27=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date27:
                price2=tmp['4. close'][j]  # 8.23.2019
                price1=tmp['4. close'][j-1]  #8.22.2019
                b=[i,price1,price2]
                a27.append(b)
                break

# %%
len(a27)
# Out:
# 4779

# %%
df27 = pd.DataFrame(a27, columns = ['Stock Name','Price 08/22/2019','Price 08/23/2019']) 
df27
# Out:
#      Stock Name  Price 08/22/2019  Price 08/23/2019
# 0         "PIH"            4.9005             4.850
# 1        "FLWS"           17.0600            15.290
# 2        "SRCE"           44.4000            42.710
# 3        "VNET"            7.7200             7.630
# 4        "TWOU"           17.7600            17.830
# 5        "JOBS"           68.0000            66.870
# 6        "EGHT"           24.8900            24.540
# 7        "AAON"           47.1200            45.580
# 8        "ABEO"            2.0400             1.830
# 9        "ABIL"            0.6900             0.651
# 10       "ABMD"          195.4400           189.590
# 11       "AXAS"            0.5800             0.500
# 12       "ACIA"           63.7100            62.850
# 13       "ACTG"            2.8800             2.710
# 14       "ACHC"           27.3300            26.430
# 15       "ACAD"           29.2100            28.050
# 16       "ACST"            1.8700             1.830
# ...

# %%
df27.to_csv('08232019.csv')

# %%
a28=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date28:
                price2=tmp['4. close'][j]  # 9.20.2019
                price1=tmp['4. close'][j-1]  #9.19.2019
                b=[i,price1,price2]
                a28.append(b)
                break

# %%
len(a28)
# Out:
# 4779

# %%
df28 = pd.DataFrame(a28, columns = ['Stock Name','Price 09/19/2019','Price 09/20/2019']) 
df28
# Out:
#      Stock Name  Price 09/19/2019  Price 09/20/2019
# 0         "PIH"             5.040             4.660
# 1        "FLWS"            14.060            14.220
# 2        "SRCE"            47.170            46.820
# 3        "VNET"             8.430             8.270
# 4        "TWOU"            17.810            17.470
# 5        "JOBS"            73.500            73.100
# 6        "EGHT"            23.890            23.420
# 7        "AAON"            49.570            48.900
# 8        "ABEO"             3.240             3.260
# 9        "ABIL"             0.608             0.593
# 10       "ABMD"           192.320           192.760
# 11       "AXAS"             0.600             0.590
# 12       "ACIA"            64.310            64.580
# 13       "ACTG"             2.670             2.750
# 14       "ACHC"            32.310            32.760
# 15       "ACAD"            41.680            40.740
# 16       "ACST"             2.140             2.110
# ...

# %%
df28.to_csv('09202019.csv')

# %%
a29=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date29:
                price2=tmp['4. close'][j]  # 9.23.2019
                price1=tmp['4. close'][j-1]  #9.22.2019
                b=[i,price1,price2]
                a29.append(b)
                break

# %%
len(a29)
# Out:
# 4779

# %%
df29 = pd.DataFrame(a29, columns = ['Stock Name','Price 09/22/2019','Price 09/23/2019']) 
df29
# Out:
#      Stock Name  Price 09/22/2019  Price 09/23/2019
# 0         "PIH"             4.660             4.860
# 1        "FLWS"            14.220            14.330
# 2        "SRCE"            46.820            46.770
# 3        "VNET"             8.270             8.360
# 4        "TWOU"            17.470            17.170
# 5        "JOBS"            73.100            71.350
# 6        "EGHT"            23.420            23.270
# 7        "AAON"            48.900            48.280
# 8        "ABEO"             3.260             2.870
# 9        "ABIL"             0.593             0.616
# 10       "ABMD"           192.760           186.010
# 11       "AXAS"             0.590             0.570
# 12       "ACIA"            64.580            64.460
# 13       "ACTG"             2.750             2.740
# 14       "ACHC"            32.760            32.870
# 15       "ACAD"            40.740            41.610
# 16       "ACST"             2.110             2.100
# ...

# %%
df29.to_csv('09232019.csv')

# %%
a30=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date30:
                price2=tmp['4. close'][j]  # 10.07.2019
                price1=tmp['4. close'][j-1]  #10.6.2019
                b=[i,price1,price2]
                a30.append(b)
                break

# %%
len(a30)
# Out:
# 4779

# %%
df30 = pd.DataFrame(a30, columns = ['Stock Name','Price 10/06/2019','Price 10/07/2019']) 
df30
# Out:
#      Stock Name  Price 10/06/2019  Price 10/07/2019
# 0         "PIH"              4.86             4.700
# 1        "FLWS"             14.59            14.490
# 2        "SRCE"             45.18            45.230
# 3        "VNET"              7.49             7.490
# 4        "TWOU"             16.38            16.430
# 5        "JOBS"             74.88            75.210
# 6        "EGHT"             19.91            20.180
# 7        "AAON"             45.29            44.950
# 8        "ABEO"              2.25             2.380
# 9        "ABIL"              0.50             0.471
# 10       "ABMD"            169.25           164.430
# 11       "AXAS"              0.44             0.410
# 12       "ACIA"             65.35            65.550
# 13       "ACTG"              2.55             2.540
# 14       "ACHC"             29.86            29.670
# 15       "ACAD"             38.16            38.700
# 16       "ACST"              1.87             1.950
# ...

# %%
df30.to_csv('10072019.csv')

# %%
a31=[]
for i in joinlist: 
    tmp=pd.read_csv('data/'+i[1:-1]+'.csv')
    dates=pd.to_datetime(tmp['date'])
    for j in range(len(dates)):
            if dates[j] >= date31:
                price2=tmp['4. close'][j]  # 10.10.2019
                price1=tmp['4. close'][j-1]  #10.09.2019
                b=[i,price1,price2]
                a31.append(b)
                break

# %%
len(a31)
# Out:
# 4779

# %%
df31 = pd.DataFrame(a31, columns = ['Stock Name','Price 10/09/2019','Price 10/10/2019']) 
df31
# Out:
#      Stock Name  Price 10/09/2019  Price 10/10/2019
# 0         "PIH"              4.60             4.520
# 1        "FLWS"             13.93            13.920
# 2        "SRCE"             44.58            44.600
# 3        "VNET"              7.21             7.190
# 4        "TWOU"             16.11            15.770
# 5        "JOBS"             76.74            78.010
# 6        "EGHT"             19.95            19.570
# 7        "AAON"             45.12            45.510
# 8        "ABEO"              2.21             2.200
# 9        "ABIL"              0.48             0.457
# 10       "ABMD"            159.31           162.340
# 11       "AXAS"              0.38             0.370
# 12       "ACIA"             65.11            64.970
# 13       "ACTG"              2.52             2.570
# 14       "ACHC"             29.19            28.920
# 15       "ACAD"             39.88            40.480
# 16       "ACST"              2.10             2.130
# ...

# %%
df30.to_csv('10102019.csv')
