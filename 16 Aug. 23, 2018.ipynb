# %%
#16 Aug. 23, 2018       S&P 500: -0.17%

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from kneed import DataGenerator, KneeLocator

# %%
data = pd.read_csv("16.csv") 
price1=np.zeros(4779)
price2=np.zeros(4779)
price1=data['Price 08/22/2018'].values
price2=data['Price 08/23/2018'].values
pricechange=(price2-price1)/price1
pricechange.shape
x=np.arange(4779)
plt.plot(x,pricechange)
plt.ylim(-2,10)
plt.show()

# %%
for i in range(4779):
    if pricechange[i]>10:
        print(i,pricechange[i])
        pricechange[i]=0
plt.plot(x,pricechange)
#plt.ylim(-2,10)
plt.show()
# Out:
# 67 25.349999999999994
# 728 22.333333333333336
# 989 21.35714285714286
# 1309 35.19047619047619
# 1627 138.57142857142856
# 2063 23.12
# 2091 27473.999999999996
# 2104 45.075949367088604
# 2416 11.407079646017701
# 2434 10.049250535331906
# 3026 329.4347826086957
# 3435 3225.6666666666665
# 3483 2095.0
# 3568 72.14
# 3815 139.76923076923075
# 4048 180.48148148148147
# 4098 110.37037037037037
# 4275 695.4285714285714
# 4436 21.181818181818183
# 4698 2049.0

# %%
cluster_distance=[]
clusters=[]
for k in range(10,50): #try to find the elbow point 
    price3index=np.zeros((4779,2))  #2*4779 table 
    center=(np.random.rand(k)-0.5)*0.1  #random choose centers 
    total=0
    for j in range(100):     #iteration
        for i in range(4779):
            distance=np.abs(pricechange[i]-center)  #distance between each center to each point
            price3index[i]=[np.argmin(distance),np.min(distance)]   #index and shortest distance
        count=np.zeros((k,2))
        for i in range(4779):
            count[int(price3index[i][0])][0]+=1  #how many stocks in each cluster 
            count[int(price3index[i][0])][1]+=pricechange[i]   #sum of distance in each cluster
            center=count[:,1]/(count[:,0]+1e-9)  #new centers

    for i in range(4779):
        total=total+price3index[i][1] #shortest total distance of each point to its center point
    print('Cluster Number:',k,'Total Distance:',total)
    cluster_distance.append(total)
    clusters.append(k)
# Out:
# Cluster Number: 10 Total Distance: 42.067914319006114
# Cluster Number: 11 Total Distance: 39.09021817706791
# Cluster Number: 12 Total Distance: 37.100110996191134
# Cluster Number: 13 Total Distance: 33.141253092330295
# Cluster Number: 14 Total Distance: 31.2863854694166
# Cluster Number: 15 Total Distance: 28.808152864719744
# Cluster Number: 16 Total Distance: 28.79992174911954
# Cluster Number: 17 Total Distance: 26.759365179950624
# Cluster Number: 18 Total Distance: 26.181411351911805
# Cluster Number: 19 Total Distance: 25.41807052919765
# Cluster Number: 20 Total Distance: 24.323078193864212
# Cluster Number: 21 Total Distance: 23.36316690995909
# Cluster Number: 22 Total Distance: 22.926987096330727
# Cluster Number: 23 Total Distance: 22.13669960997881
# Cluster Number: 24 Total Distance: 21.446423944167755
# Cluster Number: 25 Total Distance: 21.64147999884659
# Cluster Number: 26 Total Distance: 20.993743658271296
# Cluster Number: 27 Total Distance: 20.434573988263946
# Cluster Number: 28 Total Distance: 20.242027958649132
# Cluster Number: 29 Total Distance: 20.6381349178239
# Cluster Number: 30 Total Distance: 19.757374586299644
# Cluster Number: 31 Total Distance: 19.863590229331926
# Cluster Number: 32 Total Distance: 19.467275349470498
# Cluster Number: 33 Total Distance: 19.085912556333486
# Cluster Number: 34 Total Distance: 19.199833179375116
# Cluster Number: 35 Total Distance: 18.84279896676413
# Cluster Number: 36 Total Distance: 18.753611130314358
# Cluster Number: 37 Total Distance: 18.765141160574434
# Cluster Number: 38 Total Distance: 18.607590849347662
# Cluster Number: 39 Total Distance: 18.36911467698649
# Cluster Number: 40 Total Distance: 18.346802712093716
# Cluster Number: 41 Total Distance: 18.30739070703921
# Cluster Number: 42 Total Distance: 19.47159608691973
# Cluster Number: 43 Total Distance: 18.150305112127633
# Cluster Number: 44 Total Distance: 18.578354106362802
# Cluster Number: 45 Total Distance: 17.840601833142173
# Cluster Number: 46 Total Distance: 17.736427436726757
# Cluster Number: 47 Total Distance: 17.830416793520925
# Cluster Number: 48 Total Distance: 18.637414366468512
# Cluster Number: 49 Total Distance: 17.400469287146123

# %%
fig=plt.figure()

x=clusters
y=cluster_distance

kn=KneeLocator(x, y, curve='convex', direction='decreasing')


plt.plot(x, y,color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=6)

plt.vlines(kn.knee,10, 50,linestyles='dashed',color='orange')

# naming the x axis 
plt.xlabel('Number of Clusters') 
# naming the y axis 
plt.ylabel('Sum Distance of Each Point to its Centroid') 
  
# giving a title to my graph 
plt.title('16 Finding Elbow Point') 
  
# function to show the plot 
plt.show()

# %%
kn.knee
# Out:
# 24

# %%
fig.savefig('16 Aug23 2018.png')
