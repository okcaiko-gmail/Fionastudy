# %%
#14 Aug. 1, 2018        S&P 500: -0.10%

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from kneed import DataGenerator, KneeLocator

# %%
data = pd.read_csv("14.csv") 
price1=np.zeros(4779)
price2=np.zeros(4779)
price1=data['Price 07/31/2018'].values
price2=data['Price 08/01/2018'].values
pricechange=(price2-price1)/price1
pricechange.shape
x=np.arange(4779)
plt.plot(x,pricechange)
plt.ylim(-2,10)
plt.show()

# %%
for i in range(4779):
    if pricechange[i]>10:
        print(i,pricechange[i])
        pricechange[i]=0
plt.plot(x,pricechange)
#plt.ylim(-2,10)
plt.show()
# Out:
# 67 25.349999999999994
# 728 22.333333333333336
# 989 21.35714285714286
# 1309 35.19047619047619
# 1627 138.57142857142856
# 1782 23.365853658536587
# 2063 23.12
# 2091 27473.999999999996
# 2104 45.075949367088604
# 2416 11.407079646017701
# 2434 10.049250535331906
# 3026 329.4347826086957
# 3435 3225.6666666666665
# 3483 2095.0
# 3815 139.76923076923075
# 4048 180.48148148148147
# 4098 110.37037037037037
# 4275 695.4285714285714
# 4436 21.181818181818183
# 4698 2049.0

# %%
cluster_distance=[]
clusters=[]
for k in range(10,50): #try to find the elbow point 
    price3index=np.zeros((4779,2))  #2*4779 table 
    center=(np.random.rand(k)-0.5)*0.1  #random choose centers 
    total=0
    for j in range(100):     #iteration
        for i in range(4779):
            distance=np.abs(pricechange[i]-center)  #distance between each center to each point
            price3index[i]=[np.argmin(distance),np.min(distance)]   #index and shortest distance
        count=np.zeros((k,2))
        for i in range(4779):
            count[int(price3index[i][0])][0]+=1  #how many stocks in each cluster 
            count[int(price3index[i][0])][1]+=pricechange[i]   #sum of distance in each cluster
            center=count[:,1]/(count[:,0]+1e-9)  #new centers

    for i in range(4779):
        total=total+price3index[i][1] #shortest total distance of each point to its center point
    print('Cluster Number:',k,'Total Distance:',total)
    cluster_distance.append(total)
    clusters.append(k)
# Out:
# Cluster Number: 10 Total Distance: 47.0007020603439
# Cluster Number: 11 Total Distance: 43.1722700355054
# Cluster Number: 12 Total Distance: 40.33806591514967
# Cluster Number: 13 Total Distance: 36.947269377605366
# Cluster Number: 14 Total Distance: 35.0876354067483
# Cluster Number: 15 Total Distance: 32.32040319765806
# Cluster Number: 16 Total Distance: 31.01292266051402
# Cluster Number: 17 Total Distance: 29.59412310788384
# Cluster Number: 18 Total Distance: 27.603602270453624
# Cluster Number: 19 Total Distance: 26.51313619300253
# Cluster Number: 20 Total Distance: 25.267831895801994
# Cluster Number: 21 Total Distance: 23.951422813977526
# Cluster Number: 22 Total Distance: 23.566585359206464
# Cluster Number: 23 Total Distance: 23.294637344051985
# Cluster Number: 24 Total Distance: 21.721729063912996
# Cluster Number: 25 Total Distance: 22.06195188066743
# Cluster Number: 26 Total Distance: 22.248819890254065
# Cluster Number: 27 Total Distance: 20.62913223439766
# Cluster Number: 28 Total Distance: 19.731158894804736
# Cluster Number: 29 Total Distance: 19.680488299778553
# Cluster Number: 30 Total Distance: 19.06819349028285
# Cluster Number: 31 Total Distance: 18.896448613465434
# Cluster Number: 32 Total Distance: 19.44508544184477
# Cluster Number: 33 Total Distance: 18.229399073881257
# Cluster Number: 34 Total Distance: 18.05401807038267
# Cluster Number: 35 Total Distance: 18.197722096091454
# Cluster Number: 36 Total Distance: 17.626677499647812
# Cluster Number: 37 Total Distance: 17.625143833434823
# Cluster Number: 38 Total Distance: 17.138854083335552
# Cluster Number: 39 Total Distance: 17.224191100111224
# Cluster Number: 40 Total Distance: 17.416947472487916
# Cluster Number: 41 Total Distance: 16.818317836791273
# Cluster Number: 42 Total Distance: 17.190366033066073
# Cluster Number: 43 Total Distance: 16.739356768889426
# Cluster Number: 44 Total Distance: 16.314112583672834
# Cluster Number: 45 Total Distance: 16.47678956472007
# Cluster Number: 46 Total Distance: 16.160079560365276
# Cluster Number: 47 Total Distance: 16.240262123850297
# Cluster Number: 48 Total Distance: 16.060050748442602
# Cluster Number: 49 Total Distance: 16.0017972157382

# %%
fig=plt.figure()

x=clusters
y=cluster_distance

kn=KneeLocator(x, y, curve='convex', direction='decreasing')


plt.plot(x, y,color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=8)

plt.vlines(kn.knee,10, 24,linestyles='dashed',color='orange')

# naming the x axis 
plt.xlabel('Number of Clusters') 
# naming the y axis 
plt.ylabel('Sum Distance of Each Point to its Centroid') 
  
# giving a title to my graph 
plt.title('14 Finding Elbow Point') 
  
# function to show the plot 
plt.show()

# %%
kn.knee
# Out:
# 21

# %%
fig.savefig('14 Aug1 2018.png')
