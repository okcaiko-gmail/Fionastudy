# %%
#11 April 4, 2018       S&P 500: +1.16%

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from kneed import DataGenerator, KneeLocator

# %%
data = pd.read_csv("11.csv") 
price1=np.zeros(4779)
price2=np.zeros(4779)
price1=data['Price 04/03/2018'].values
price2=data['Price 04/04/2018'].values
pricechange=(price2-price1)/price1
pricechange.shape
x=np.arange(4779)
plt.plot(x,pricechange)
plt.ylim(-2,10)
plt.show()

# %%
for i in range(4779):
    if pricechange[i]>10:
        print(i,pricechange[i])
        pricechange[i]=0
plt.plot(x,pricechange)
#plt.ylim(-2,10)
plt.show()
# Out:
# 67 25.349999999999994
# 219 29.344827586206904
# 288 19.833333333333332
# 443 10.063829787234043
# 656 14.166666666666666
# 728 22.333333333333336
# 989 21.35714285714286
# 1309 35.19047619047619
# 1542 1459.0
# 1627 138.57142857142856
# 1782 23.365853658536587
# 2063 23.12
# 2091 27473.999999999996
# 2104 45.075949367088604
# 2416 11.407079646017701
# 2434 10.049250535331906
# 3026 329.4347826086957
# 3460 7223.999999999999
# 3483 2095.0
# 3815 139.76923076923075
# 4048 180.48148148148147
# 4098 110.37037037037037
# 4240 24898.999999999996
# 4275 695.4285714285714
# 4436 21.181818181818183
# 4698 2049.0

# %%
cluster_distance=[]
clusters=[]
for k in range(13,50): #try to find the elbow point 
    price3index=np.zeros((4779,2))  #2*4779 table 
    center=(np.random.rand(k)-0.5)*0.1  #random choose centers 
    total=0
    for j in range(100):     #iteration
        for i in range(4779):
            distance=np.abs(pricechange[i]-center)  #distance between each center to each point
            price3index[i]=[np.argmin(distance),np.min(distance)]   #index and shortest distance
        count=np.zeros((k,2))
        for i in range(4779):
            count[int(price3index[i][0])][0]+=1  #how many stocks in each cluster 
            count[int(price3index[i][0])][1]+=pricechange[i]   #sum of distance in each cluster
            center=count[:,1]/(count[:,0]+1e-9)  #new centers

    for i in range(4779):
        total=total+price3index[i][1] #shortest total distance of each point to its center point
    print('Cluster Number:',k,'Total Distance:',total)
    cluster_distance.append(total)
    clusters.append(k)
# Out:
# Cluster Number: 13 Total Distance: 39.69297525011885
# Cluster Number: 14 Total Distance: 35.9690742785866
# Cluster Number: 15 Total Distance: 34.5463426522119
# Cluster Number: 16 Total Distance: 33.99750286721456
# Cluster Number: 17 Total Distance: 30.633668068600166
# Cluster Number: 18 Total Distance: 29.013205998624265
# Cluster Number: 19 Total Distance: 27.81901143255467
# Cluster Number: 20 Total Distance: 27.892028156172202
# Cluster Number: 21 Total Distance: 26.06767586283876
# Cluster Number: 22 Total Distance: 25.039448206224343
# Cluster Number: 23 Total Distance: 25.914609941823198
# Cluster Number: 24 Total Distance: 23.878571860440466
# Cluster Number: 25 Total Distance: 24.38244947941612
# Cluster Number: 26 Total Distance: 22.733164572522803
# Cluster Number: 27 Total Distance: 23.3896540163012
# Cluster Number: 28 Total Distance: 23.142379233347597
# Cluster Number: 29 Total Distance: 21.312518317101517
# Cluster Number: 30 Total Distance: 22.099409616104825
# Cluster Number: 31 Total Distance: 21.050646805667597
# Cluster Number: 32 Total Distance: 20.936415430373557
# Cluster Number: 33 Total Distance: 20.372916854605513
# Cluster Number: 34 Total Distance: 20.23460204521447
# Cluster Number: 35 Total Distance: 19.759392960240877
# Cluster Number: 36 Total Distance: 19.830548762355548
# Cluster Number: 37 Total Distance: 20.477289650243726
# Cluster Number: 38 Total Distance: 19.301731098987023
# Cluster Number: 39 Total Distance: 20.392948670109615
# Cluster Number: 40 Total Distance: 18.729409709197984
# Cluster Number: 41 Total Distance: 19.31685075677972
# Cluster Number: 42 Total Distance: 18.910144407536745
# Cluster Number: 43 Total Distance: 18.82564473851503
# Cluster Number: 44 Total Distance: 18.8739997262534
# Cluster Number: 45 Total Distance: 17.990330548493926
# Cluster Number: 46 Total Distance: 18.342680877241023
# Cluster Number: 47 Total Distance: 18.165712835400317
# Cluster Number: 48 Total Distance: 18.162306604075706
# Cluster Number: 49 Total Distance: 17.897982579540823

# %%
fig=plt.figure()

x=clusters
y=cluster_distance

kn=KneeLocator(x, y, curve='convex', direction='decreasing')


plt.plot(x, y,color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=8)

plt.vlines(kn.knee,10, 40,linestyles='dashed',color='orange')

# naming the x axis 
plt.xlabel('Number of Clusters') 
# naming the y axis 
plt.ylabel('Sum Distance of Each Point to its Centroid') 
  
# giving a title to my graph 
plt.title('11 Finding Elbow Point') 
  
# function to show the plot 
plt.show()

# %%
kn.knee
# Out:
# 19

# %%
fig.savefig('11 April4 2018.png')
